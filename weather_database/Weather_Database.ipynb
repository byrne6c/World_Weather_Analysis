# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import time module
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters (set at 1 for the 1st iteration of logging for each recorded response.
record_count = 1
set_count = 1

# use the enumerate() method as an alt way to iterate through the list of cities and retrieve both city & its index from the list.
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 
    # Run an API request for each of the cities. Include try-except.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description}) 

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | naze
# Processing Record 2 of Set 1 | college
# Processing Record 3 of Set 1 | buchanan
# Processing Record 4 of Set 1 | araripe
# Processing Record 5 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | pinhao
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | kefamenanu
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | peniche
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | hofn
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | badhni kalan
# Processing Record 24 of Set 1 | barra do bugres
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | dandong
# Processing Record 27 of Set 1 | faya
# Processing Record 28 of Set 1 | mount gambier
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | vestmanna
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | ziro
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | conde
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | linhares
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | leshukonskoye
# Processing Record 5 of Set 2 | balkanabat
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | znamenskoye
# Processing Record 9 of Set 2 | mityana
# Processing Record 10 of Set 2 | sola
# Processing Record 11 of Set 2 | port hardy
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | palu
# Processing Record 15 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | teguise
# Processing Record 21 of Set 2 | tupelo
# Processing Record 22 of Set 2 | dodoma
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | haines junction
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | alice springs
# Processing Record 29 of Set 2 | amudat
# Processing Record 30 of Set 2 | dhidhdhoo
# Processing Record 31 of Set 2 | catio
# Processing Record 32 of Set 2 | aksu
# Processing Record 33 of Set 2 | fayaoue
# Processing Record 34 of Set 2 | mayor pablo lagerenza
# Processing Record 35 of Set 2 | alvorada
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | alofi
# Processing Record 38 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | pudozh
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | takoradi
# Processing Record 48 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | charters towers
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | nyaunglebin
# Processing Record 5 of Set 3 | flin flon
# Processing Record 6 of Set 3 | olinda
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | rabo de peixe
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | talnakh
# Processing Record 12 of Set 3 | lazaro cardenas
# Processing Record 13 of Set 3 | mukhen
# Processing Record 14 of Set 3 | lufilufi
# Processing Record 15 of Set 3 | muisne
# Processing Record 16 of Set 3 | bustonkala
# City not found. Skipping...
# Processing Record 17 of Set 3 | aswan
# Processing Record 18 of Set 3 | ortakoy
# Processing Record 19 of Set 3 | kharabali
# Processing Record 20 of Set 3 | inyonga
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | polonnaruwa
# Processing Record 23 of Set 3 | penzance
# Processing Record 24 of Set 3 | zanjan
# Processing Record 25 of Set 3 | roald
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | muros
# Processing Record 28 of Set 3 | pakenham
# Processing Record 29 of Set 3 | bulolo
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | filimonovo
# Processing Record 32 of Set 3 | benghazi
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | raudeberg
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | biltine
# Processing Record 40 of Set 3 | koslan
# Processing Record 41 of Set 3 | keetmanshoop
# Processing Record 42 of Set 3 | arman
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | mareeba
# Processing Record 45 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 3 | tual
# Processing Record 47 of Set 3 | korla
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | kloulklubed
# Processing Record 50 of Set 3 | tateyama
# Processing Record 1 of Set 4 | fare
# Processing Record 2 of Set 4 | walvis bay
# Processing Record 3 of Set 4 | meulaboh
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | limulunga
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | yatou
# Processing Record 9 of Set 4 | salinas
# Processing Record 10 of Set 4 | sakakah
# Processing Record 11 of Set 4 | moerai
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | maceio
# Processing Record 14 of Set 4 | izumo
# Processing Record 15 of Set 4 | samarai
# Processing Record 16 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | chilmari
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | ledyard
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | ivanovka
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | amherst
# Processing Record 26 of Set 4 | rocha
# Processing Record 27 of Set 4 | barmer
# Processing Record 28 of Set 4 | auray
# Processing Record 29 of Set 4 | encantado
# Processing Record 30 of Set 4 | shingu
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | caravelas
# Processing Record 33 of Set 4 | andilamena
# Processing Record 34 of Set 4 | tongchuan
# Processing Record 35 of Set 4 | acara
# Processing Record 36 of Set 4 | sarangani
# Processing Record 37 of Set 4 | santa cruz del sur
# Processing Record 38 of Set 4 | amarante do maranhao
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | birjand
# Processing Record 41 of Set 4 | viedma
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | zhangye
# Processing Record 44 of Set 4 | tumarbong
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | amos
# Processing Record 47 of Set 4 | wattegama
# Processing Record 48 of Set 4 | hobyo
# Processing Record 49 of Set 4 | tolaga bay
# Processing Record 50 of Set 4 | tonantins
# Processing Record 1 of Set 5 | posse
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 5 | frontera
# Processing Record 6 of Set 5 | sahuaripa
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | ulagan
# Processing Record 9 of Set 5 | sao jose da coroa grande
# Processing Record 10 of Set 5 | guarapari
# Processing Record 11 of Set 5 | tahoua
# Processing Record 12 of Set 5 | balkhash
# Processing Record 13 of Set 5 | ranong
# Processing Record 14 of Set 5 | nhulunbuy
# Processing Record 15 of Set 5 | te anau
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | yellowknife
# Processing Record 18 of Set 5 | nikolskoye
# Processing Record 19 of Set 5 | anadyr
# Processing Record 20 of Set 5 | umm lajj
# Processing Record 21 of Set 5 | salinopolis
# Processing Record 22 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 5 | kerema
# Processing Record 24 of Set 5 | odweyne
# Processing Record 25 of Set 5 | santarem
# Processing Record 26 of Set 5 | hit
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | feni
# Processing Record 31 of Set 5 | usinsk
# Processing Record 32 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 5 | tashtagol
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | obo
# Processing Record 36 of Set 5 | vertientes
# Processing Record 37 of Set 5 | pacific grove
# Processing Record 38 of Set 5 | poya
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | staryy nadym
# Processing Record 41 of Set 5 | whitehorse
# Processing Record 42 of Set 5 | soe
# Processing Record 43 of Set 5 | nizhniy chir
# Processing Record 44 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | mahanje
# Processing Record 47 of Set 5 | abonnema
# Processing Record 48 of Set 5 | bemidji
# Processing Record 49 of Set 5 | xuddur
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | ternate
# Processing Record 2 of Set 6 | muragachha
# City not found. Skipping...
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | bonavista
# Processing Record 5 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 6 | manado
# Processing Record 7 of Set 6 | brae
# Processing Record 8 of Set 6 | gombong
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | ewa beach
# Processing Record 11 of Set 6 | general pico
# Processing Record 12 of Set 6 | vilyuysk
# Processing Record 13 of Set 6 | jibuti
# Processing Record 14 of Set 6 | axim
# Processing Record 15 of Set 6 | ghanzi
# Processing Record 16 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 17 of Set 6 | husavik
# Processing Record 18 of Set 6 | sinnamary
# Processing Record 19 of Set 6 | cairns
# Processing Record 20 of Set 6 | kokopo
# Processing Record 21 of Set 6 | lagunas
# Processing Record 22 of Set 6 | flic en flac
# Processing Record 23 of Set 6 | kiboga
# Processing Record 24 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 25 of Set 6 | lexington park
# Processing Record 26 of Set 6 | silver city
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | puerto ayora
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | luba
# Processing Record 31 of Set 6 | nuuk
# Processing Record 32 of Set 6 | gat
# Processing Record 33 of Set 6 | isangel
# Processing Record 34 of Set 6 | virginia beach
# Processing Record 35 of Set 6 | ulaangom
# Processing Record 36 of Set 6 | porterville
# Processing Record 37 of Set 6 | chifeng
# Processing Record 38 of Set 6 | vila
# Processing Record 39 of Set 6 | sechura
# Processing Record 40 of Set 6 | beyneu
# Processing Record 41 of Set 6 | chimbote
# Processing Record 42 of Set 6 | gambela
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | carnarvon
# Processing Record 45 of Set 6 | waingapu
# Processing Record 46 of Set 6 | ongole
# Processing Record 47 of Set 6 | presidente epitacio
# Processing Record 48 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 6 | nishihara
# Processing Record 50 of Set 6 | kipushi
# Processing Record 1 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 2 of Set 7 | moose factory
# Processing Record 3 of Set 7 | christchurch
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | severomuysk
# Processing Record 6 of Set 7 | namatanai
# Processing Record 7 of Set 7 | teul
# City not found. Skipping...
# Processing Record 8 of Set 7 | nelson bay
# Processing Record 9 of Set 7 | xinzhi
# Processing Record 10 of Set 7 | plettenberg bay
# Processing Record 11 of Set 7 | birao
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | komsomolskiy
# Processing Record 14 of Set 7 | yulara
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | quatre cocos
# Processing Record 17 of Set 7 | karratha
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | tucuman
# Processing Record 20 of Set 7 | kuching
# Processing Record 21 of Set 7 | acari
# Processing Record 22 of Set 7 | robertson
# Processing Record 23 of Set 7 | alyangula
# Processing Record 24 of Set 7 | lorengau
# Processing Record 25 of Set 7 | broome
# Processing Record 26 of Set 7 | youkounkoun
# Processing Record 27 of Set 7 | daman
# Processing Record 28 of Set 7 | lagoa
# Processing Record 29 of Set 7 | dalbandin
# Processing Record 30 of Set 7 | groa
# Processing Record 31 of Set 7 | chalmette
# Processing Record 32 of Set 7 | castro
# Processing Record 33 of Set 7 | ipixuna
# Processing Record 34 of Set 7 | gold coast
# Processing Record 35 of Set 7 | knysna
# Processing Record 36 of Set 7 | camacha
# Processing Record 37 of Set 7 | abha
# Processing Record 38 of Set 7 | tamiahua
# Processing Record 39 of Set 7 | mata
# Processing Record 40 of Set 7 | chiredzi
# Processing Record 41 of Set 7 | tevriz
# Processing Record 42 of Set 7 | hamilton
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | kinkala
# Processing Record 45 of Set 7 | yingshang
# City not found. Skipping...
# Processing Record 46 of Set 7 | ola
# Processing Record 47 of Set 7 | cedar city
# Processing Record 48 of Set 7 | mabaruma
# Processing Record 49 of Set 7 | kodiak
# Processing Record 50 of Set 7 | ketchikan
# Processing Record 1 of Set 8 | petropavlovka
# Processing Record 2 of Set 8 | toamasina
# Processing Record 3 of Set 8 | badak
# Processing Record 4 of Set 8 | kommunisticheskiy
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | ossora
# Processing Record 7 of Set 8 | xiangdong
# City not found. Skipping...
# Processing Record 8 of Set 8 | chateauroux
# Processing Record 9 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 8 | santa ines
# Processing Record 13 of Set 8 | houma
# Processing Record 14 of Set 8 | tibati
# Processing Record 15 of Set 8 | beringovskiy
# Processing Record 16 of Set 8 | tambopata
# Processing Record 17 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 18 of Set 8 | garmsar
# Processing Record 19 of Set 8 | vao
# Processing Record 20 of Set 8 | ixtapa
# Processing Record 21 of Set 8 | dunedin
# Processing Record 22 of Set 8 | tura
# Processing Record 23 of Set 8 | okhotsk
# Processing Record 24 of Set 8 | mataro
# Processing Record 25 of Set 8 | san juan
# Processing Record 26 of Set 8 | kijang
# Processing Record 27 of Set 8 | hasaki
# Processing Record 28 of Set 8 | beboto
# Processing Record 29 of Set 8 | zhangjiakou
# Processing Record 30 of Set 8 | marsa matruh
# Processing Record 31 of Set 8 | touba
# Processing Record 32 of Set 8 | gimli
# Processing Record 33 of Set 8 | opuwo
# Processing Record 34 of Set 8 | vanimo
# Processing Record 35 of Set 8 | isla vista
# Processing Record 36 of Set 8 | ubinskoye
# Processing Record 37 of Set 8 | tanhacu
# Processing Record 38 of Set 8 | abnub
# Processing Record 39 of Set 8 | pemangkat
# Processing Record 40 of Set 8 | guymon
# Processing Record 41 of Set 8 | leningradskiy
# Processing Record 42 of Set 8 | mangochi
# Processing Record 43 of Set 8 | lethem
# Processing Record 44 of Set 8 | wagar
# Processing Record 45 of Set 8 | labuhan
# Processing Record 46 of Set 8 | guiglo
# Processing Record 47 of Set 8 | goderich
# Processing Record 48 of Set 8 | jumla
# Processing Record 49 of Set 8 | jeremoabo
# Processing Record 50 of Set 8 | la cumbre
# Processing Record 1 of Set 9 | northam
# Processing Record 2 of Set 9 | pajapan
# Processing Record 3 of Set 9 | metro
# Processing Record 4 of Set 9 | port lincoln
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | buin
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | naryan-mar
# Processing Record 9 of Set 9 | otjimbingwe
# Processing Record 10 of Set 9 | makueni
# Processing Record 11 of Set 9 | ust-kuyga
# Processing Record 12 of Set 9 | saint-pierre
# Processing Record 13 of Set 9 | klaksvik
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | dhanera
# Processing Record 16 of Set 9 | beloha
# Processing Record 17 of Set 9 | vancouver
# Processing Record 18 of Set 9 | hambantota
# Processing Record 19 of Set 9 | trat
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | necochea
# Processing Record 22 of Set 9 | wanaka
# Processing Record 23 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 9 | grande-riviere
# City not found. Skipping...
# Processing Record 25 of Set 9 | paracatu
# Processing Record 26 of Set 9 | hilo
# Processing Record 27 of Set 9 | lazarev
# Processing Record 28 of Set 9 | antofagasta
# Processing Record 29 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 30 of Set 9 | ostersund
# Processing Record 31 of Set 9 | sangar
# Processing Record 32 of Set 9 | santa cruz
# Processing Record 33 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 9 | nanortalik
# Processing Record 35 of Set 9 | yangambi
# Processing Record 36 of Set 9 | tongliao
# Processing Record 37 of Set 9 | baytown
# Processing Record 38 of Set 9 | north myrtle beach
# Processing Record 39 of Set 9 | fort myers beach
# Processing Record 40 of Set 9 | margate
# Processing Record 41 of Set 9 | tarko-sale
# Processing Record 42 of Set 9 | westport
# Processing Record 43 of Set 9 | victor harbor
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | guerrero negro
# Processing Record 46 of Set 9 | kidal
# Processing Record 47 of Set 9 | podosinovets
# Processing Record 48 of Set 9 | la union
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | general roca
# Processing Record 1 of Set 10 | egvekinot
# Processing Record 2 of Set 10 | chumikan
# Processing Record 3 of Set 10 | payakumbuh
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | haysville
# Processing Record 7 of Set 10 | maragogi
# Processing Record 8 of Set 10 | maniitsoq
# Processing Record 9 of Set 10 | algeciras
# Processing Record 10 of Set 10 | la vergne
# Processing Record 11 of Set 10 | melekhovo
# Processing Record 12 of Set 10 | asosa
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | jinxiang
# Processing Record 15 of Set 10 | lalin
# Processing Record 16 of Set 10 | kavieng
# Processing Record 17 of Set 10 | vardo
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 10 | montego bay
# Processing Record 21 of Set 10 | auki
# Processing Record 22 of Set 10 | ambilobe
# Processing Record 23 of Set 10 | belaya gora
# Processing Record 24 of Set 10 | yar-sale
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | valparaiso
# Processing Record 27 of Set 10 | tabatinga
# Processing Record 28 of Set 10 | mafinga
# Processing Record 29 of Set 10 | roebourne
# Processing Record 30 of Set 10 | swan hill
# Processing Record 31 of Set 10 | port augusta
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | heihe
# Processing Record 34 of Set 10 | ouegoa
# Processing Record 35 of Set 10 | magadan
# Processing Record 36 of Set 10 | aksehir
# Processing Record 37 of Set 10 | xichang
# Processing Record 38 of Set 10 | la asuncion
# Processing Record 39 of Set 10 | soyo
# Processing Record 40 of Set 10 | tome
# Processing Record 41 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 10 | xinzhou
# Processing Record 43 of Set 10 | chara
# Processing Record 44 of Set 10 | saint-joseph
# Processing Record 45 of Set 10 | manokwari
# Processing Record 46 of Set 10 | san luis
# Processing Record 47 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 10 | grimshaw
# Processing Record 49 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 10 | pangnirtung
# Processing Record 1 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 11 | alice town
# Processing Record 3 of Set 11 | cotusca
# Processing Record 4 of Set 11 | ivanteyevka
# Processing Record 5 of Set 11 | comodoro rivadavia
# Processing Record 6 of Set 11 | colac
# Processing Record 7 of Set 11 | khed brahma
# Processing Record 8 of Set 11 | hay river
# Processing Record 9 of Set 11 | airai
# Processing Record 10 of Set 11 | falkoping
# City not found. Skipping...
# Processing Record 11 of Set 11 | ati
# Processing Record 12 of Set 11 | itororo
# Processing Record 13 of Set 11 | souillac
# Processing Record 14 of Set 11 | agadez
# Processing Record 15 of Set 11 | landeck
# Processing Record 16 of Set 11 | chom bung
# City not found. Skipping...
# Processing Record 17 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 11 | filadelfia
# Processing Record 19 of Set 11 | luancheng
# Processing Record 20 of Set 11 | lokosovo
# Processing Record 21 of Set 11 | saint-georges
# Processing Record 22 of Set 11 | mahenge
# Processing Record 23 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 24 of Set 11 | honiara
# Processing Record 25 of Set 11 | taoudenni
# Processing Record 26 of Set 11 | nazilli
# Processing Record 27 of Set 11 | bowmore
# Processing Record 28 of Set 11 | taguatinga
# Processing Record 29 of Set 11 | gort
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | nantucket
# Processing Record 32 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 33 of Set 11 | tombouctou
# Processing Record 34 of Set 11 | bud
# Processing Record 35 of Set 11 | marrakesh
# Processing Record 36 of Set 11 | cordoba
# Processing Record 37 of Set 11 | cayenne
# Processing Record 38 of Set 11 | yeppoon
# Processing Record 39 of Set 11 | troitskoye
# Processing Record 40 of Set 11 | tromso
# Processing Record 41 of Set 11 | andenes
# Processing Record 42 of Set 11 | nortelandia
# Processing Record 43 of Set 11 | hirara
# Processing Record 44 of Set 11 | carballo
# Processing Record 45 of Set 11 | kars
# Processing Record 46 of Set 11 | vostok
# Processing Record 47 of Set 11 | ulladulla
# Processing Record 48 of Set 11 | zhuhai
# Processing Record 49 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 11 | amahai
# Processing Record 1 of Set 12 | matara
# Processing Record 2 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 12 | estelle
# Processing Record 4 of Set 12 | mopipi
# Processing Record 5 of Set 12 | ravar
# Processing Record 6 of Set 12 | kurumkan
# Processing Record 7 of Set 12 | evensk
# Processing Record 8 of Set 12 | le moule
# Processing Record 9 of Set 12 | rio grande
# Processing Record 10 of Set 12 | snezhnogorsk
# Processing Record 11 of Set 12 | san policarpo
# Processing Record 12 of Set 12 | gurupa
# Processing Record 13 of Set 12 | auburn
# Processing Record 14 of Set 12 | santa rosalia
# Processing Record 15 of Set 12 | chabahar
# Processing Record 16 of Set 12 | kaminskiy
# Processing Record 17 of Set 12 | bathsheba
# Processing Record 18 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 19 of Set 12 | madeji
# Processing Record 20 of Set 12 | laguna
# Processing Record 21 of Set 12 | sao felix do xingu
# Processing Record 22 of Set 12 | broken hill
# Processing Record 23 of Set 12 | kanniyakumari
# Processing Record 24 of Set 12 | yeniseysk
# Processing Record 25 of Set 12 | banyo
# Processing Record 26 of Set 12 | ouadda
# Processing Record 27 of Set 12 | yerbogachen
# Processing Record 28 of Set 12 | las vegas
# Processing Record 29 of Set 12 | padang
# Processing Record 30 of Set 12 | dharan
# Processing Record 31 of Set 12 | luwuk
# Processing Record 32 of Set 12 | ivankiv
# Processing Record 33 of Set 12 | muzhi
# Processing Record 34 of Set 12 | clyde river
# Processing Record 35 of Set 12 | san clemente
# Processing Record 36 of Set 12 | kinablangan
# Processing Record 37 of Set 12 | la trinidad
# Processing Record 38 of Set 12 | cabedelo
# Processing Record 39 of Set 12 | san borja
# Processing Record 40 of Set 12 | quang ngai
# Processing Record 41 of Set 12 | esfarayen
# Processing Record 42 of Set 12 | west point
# Processing Record 43 of Set 12 | fairbanks
# Processing Record 44 of Set 12 | aklavik
# Processing Record 45 of Set 12 | banna
# Processing Record 46 of Set 12 | praia da vitoria
# Processing Record 47 of Set 12 | zacapa
# Processing Record 48 of Set 12 | oktyabrskoye
# Processing Record 49 of Set 12 | puerto maldonado
# Processing Record 50 of Set 12 | los llanos de aridane
# Processing Record 1 of Set 13 | tazovskiy
# Processing Record 2 of Set 13 | lerwick
# Processing Record 3 of Set 13 | mnogovershinnyy
# Processing Record 4 of Set 13 | espanola
# Processing Record 5 of Set 13 | biak
# Processing Record 6 of Set 13 | batemans bay
# Processing Record 7 of Set 13 | kjopsvik
# Processing Record 8 of Set 13 | rio gallegos
# Processing Record 9 of Set 13 | izhma
# Processing Record 10 of Set 13 | ucluelet
# Processing Record 11 of Set 13 | kemijarvi
# Processing Record 12 of Set 13 | wanning
# Processing Record 13 of Set 13 | batsfjord
# Processing Record 14 of Set 13 | makasar
# Processing Record 15 of Set 13 | kafue
# Processing Record 16 of Set 13 | mackenzie
# Processing Record 17 of Set 13 | qaqortoq
# Processing Record 18 of Set 13 | kargasok
# Processing Record 19 of Set 13 | ginda
# Processing Record 20 of Set 13 | dimitrovgrad
# Processing Record 21 of Set 13 | puerto escondido
# Processing Record 22 of Set 13 | mizdah
# Processing Record 23 of Set 13 | palamos
# Processing Record 24 of Set 13 | tessalit
# Processing Record 25 of Set 13 | tricase
# Processing Record 26 of Set 13 | bengkulu
# Processing Record 27 of Set 13 | jablah
# Processing Record 28 of Set 13 | avera
# Processing Record 29 of Set 13 | port moresby
# Processing Record 30 of Set 13 | mitzic
# Processing Record 31 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 13 | nipawin
# Processing Record 33 of Set 13 | kungurtug
# Processing Record 34 of Set 13 | san alberto
# Processing Record 35 of Set 13 | norfolk
# Processing Record 36 of Set 13 | baykit
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | iqaluit
# Processing Record 39 of Set 13 | erquelinnes
# Processing Record 40 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 13 | magdagachi
# Processing Record 42 of Set 13 | nador
# Processing Record 43 of Set 13 | tetouan
# Processing Record 44 of Set 13 | altay
# Processing Record 45 of Set 13 | ayan
# Processing Record 46 of Set 13 | medea
# Processing Record 47 of Set 13 | zhigansk
# Processing Record 48 of Set 13 | atasu
# Processing Record 49 of Set 13 | petauke
# Processing Record 50 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 1 of Set 14 | berlevag
# Processing Record 2 of Set 14 | saurimo
# Processing Record 3 of Set 14 | teseney
# Processing Record 4 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 14 | leninskoye
# Processing Record 6 of Set 14 | kiunga
# Processing Record 7 of Set 14 | santa cruz de tenerife
# Processing Record 8 of Set 14 | vaitape
# Processing Record 9 of Set 14 | vila velha
# Processing Record 10 of Set 14 | tahta
# Processing Record 11 of Set 14 | tucurui
# Processing Record 12 of Set 14 | muroto
# Processing Record 13 of Set 14 | boshan
# Processing Record 14 of Set 14 | buritis
# Processing Record 15 of Set 14 | itigi
# Processing Record 16 of Set 14 | sapernoye
# Processing Record 17 of Set 14 | tigil
# Processing Record 18 of Set 14 | lasa
# Processing Record 19 of Set 14 | santiago del estero
# Processing Record 20 of Set 14 | nizhniy odes
# Processing Record 21 of Set 14 | pinas
# Processing Record 22 of Set 14 | acapulco
# Processing Record 23 of Set 14 | iskateley
# Processing Record 24 of Set 14 | aktash
# Processing Record 25 of Set 14 | dicabisagan
# Processing Record 26 of Set 14 | paamiut
# Processing Record 27 of Set 14 | shellbrook
# Processing Record 28 of Set 14 | clarence town
# Processing Record 29 of Set 14 | arica
# Processing Record 30 of Set 14 | benguela
# Processing Record 31 of Set 14 | anda
# Processing Record 32 of Set 14 | port-gentil
# Processing Record 33 of Set 14 | brewster
# Processing Record 34 of Set 14 | la cruz
# Processing Record 35 of Set 14 | wencheng
# Processing Record 36 of Set 14 | wiarton
# Processing Record 37 of Set 14 | ushumun
# Processing Record 38 of Set 14 | bandarbeyla
# Processing Record 39 of Set 14 | fukue
# Processing Record 40 of Set 14 | phek
# Processing Record 41 of Set 14 | dawlatabad
# Processing Record 42 of Set 14 | druzhba
# Processing Record 43 of Set 14 | garden city
# Processing Record 44 of Set 14 | lavrentiya
# Processing Record 45 of Set 14 | bundaberg
# Processing Record 46 of Set 14 | dwarka
# Processing Record 47 of Set 14 | taltal
# Processing Record 48 of Set 14 | madaoua
# Processing Record 49 of Set 14 | japura
# Processing Record 50 of Set 14 | kohtla-nomme
# Processing Record 1 of Set 15 | saint-leu
# Processing Record 2 of Set 15 | jacareacanga
# Processing Record 3 of Set 15 | londoko
# Processing Record 4 of Set 15 | banjar
# Processing Record 5 of Set 15 | sajanan
# Processing Record 6 of Set 15 | akureyri
# Processing Record 7 of Set 15 | pombas
# Processing Record 8 of Set 15 | miyako
# Processing Record 9 of Set 15 | verkhnevilyuysk
# Processing Record 10 of Set 15 | hyeres
# Processing Record 11 of Set 15 | todos santos
# Processing Record 12 of Set 15 | ajdabiya
# Processing Record 13 of Set 15 | ondangwa
# Processing Record 14 of Set 15 | sena madureira
# Processing Record 15 of Set 15 | saint anthony
# Processing Record 16 of Set 15 | lima
# Processing Record 17 of Set 15 | san cristobal
# Processing Record 18 of Set 15 | uporovo
# Processing Record 19 of Set 15 | bilibino
# Processing Record 20 of Set 15 | amarpatan
# Processing Record 21 of Set 15 | mayo
# Processing Record 22 of Set 15 | ambon
# Processing Record 23 of Set 15 | alta floresta
# Processing Record 24 of Set 15 | bac lieu
# Processing Record 25 of Set 15 | campo de criptana
# Processing Record 26 of Set 15 | nago
# Processing Record 27 of Set 15 | two rivers
# Processing Record 28 of Set 15 | ugoofaaru
# Processing Record 29 of Set 15 | neuquen
# Processing Record 30 of Set 15 | eureka
# Processing Record 31 of Set 15 | filingue
# Processing Record 32 of Set 15 | feuchtwangen
# Processing Record 33 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 34 of Set 15 | shibukawa
# Processing Record 35 of Set 15 | hun
# Processing Record 36 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 15 | xinyang
# Processing Record 38 of Set 15 | sai buri
# Processing Record 39 of Set 15 | atar
# Processing Record 40 of Set 15 | terekli-mekteb
# Processing Record 41 of Set 15 | bonthe
# Processing Record 42 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | malaba
# Processing Record 44 of Set 15 | mmabatho
# Processing Record 45 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 15 | tuy hoa
# Processing Record 47 of Set 15 | arkhara
# Processing Record 48 of Set 15 | linjiang
# Processing Record 49 of Set 15 | genhe
# Processing Record 50 of Set 15 | brigantine
# Processing Record 1 of Set 16 | guia lopes da laguna
# Processing Record 2 of Set 16 | jermuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Naze  28.3667  129.4833     59.92        64          99       19.66
# 1    College  64.8569 -147.8028    -27.45        67           1        0.00
# 2   Buchanan   5.8808  -10.0467     82.72        71          75        3.04
# 3    Araripe  -7.2125  -40.0461     69.33        88         100        7.43
# 4    Rikitea -23.1203 -134.9692     75.96        75         100        7.96
# 5   Thompson  55.7435  -97.8558    -25.44        75          40       10.36
# 6    Mataura -46.1927  168.8643     51.48        71          99        2.66
# 7  Esperance -33.8667  121.9000     78.64        64           0       21.14
# 8     Pinhao -25.6956  -51.6597     62.10        96          50        5.88
# 9   Cidreira -30.1811  -50.2056     70.07        67         100        9.22
#
#   Country Current Description
# 0      JP     overcast clouds
# 1      US           clear sky
# 2      LR       broken clouds
# 3      BR     overcast clouds
# 4      PF       moderate rain
# 5      CA    scattered clouds
# 6      NZ     overcast clouds
# 7      AU           clear sky
# 8      BR    scattered clouds
# 9      BR     overcast clouds

# %%
# reorder columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed" , "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV) & save dataframe in selected folder.
output_data_file = "weatherpy_database.csv"

# Export the City_Data dataframe into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
